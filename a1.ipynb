# %%
import seaborn as sns
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
import seaborn as sns
df = sns.load_dataset("taxis")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df.select_dtypes(include='object')
# Out:
#        color      payment            pickup_zone  \
# 0     yellow  credit card        Lenox Hill West
# 1     yellow         cash  Upper West Side South
# 2     yellow  credit card          Alphabet City
# 3     yellow  credit card              Hudson Sq
# 4     yellow  credit card           Midtown East
# ...      ...          ...                    ...
# 6428   green  credit card      East Harlem North
# 6429   green  credit card                Jamaica
# 6430   green         cash    Crown Heights North
# 6431   green  credit card          East New York
# 6432   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 6 columns]

# %%
df.isna().sum()/df.shape[0]
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.006840
# pickup_zone        0.004042
# dropoff_zone       0.006995
# pickup_borough     0.004042
# dropoff_borough    0.006995
# dtype: float64

# %%
df.shape[0]-df.dropna().shape[0]
# Out:
# 92

# %%
df=df.dropna()

# %%
df=df.reset_index(drop=True)

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
#EDA 
#tip is the Target column

# %%
#tip is numerical feature, analyze with color feature which categorical

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
# graphical analysis of categorical data
sns.barplot(x=df.color,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.barplot(x=df.color,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(x=df.tip,hue=df.color,kde=True,palette={'yellow':'yellow','green':'green'})
plt.show()

# %% [markdown]
# # T-Test
#
# **Definition:** T-Test is used to compare means when the population variance is unknown or the sample size is small.
#
# ---
#
# ## Independent T-Test
#
# **Example:** Compare **Annual Income** of **Male vs Female** customers.
#
# **Hypotheses:**
# - H0: distribution of tip for yellow = distribution of tip for green
# - H1: distribution of tip for yellow ≠ distribution of tip for green

# %%
yellow_tip=df['tip'][df['color']=='yellow']
green_tip=df['tip'][df['color']=='green']

# %%
yellow_tip
# Out:
# 0       2.15
# 1       0.00
# 2       2.36
# 3       6.15
# 4       1.10
#         ...
# 5368    2.66
# 5369    2.36
# 5370    2.56
# 5371    2.36
# 5372    1.33
# Name: tip, Length: 5373, dtype: float64

# %%
green_tip
# Out:
# 5373    0.00
# 5374    0.00
# 5375    1.20
# 5376    0.00
# 5377    0.00
#         ...
# 6336    1.06
# 6337    0.00
# 6338    0.00
# 6339    0.00
# 6340    3.36
# Name: tip, Length: 968, dtype: float64

# %%
green_tip.shape
# Out:
# (968,)

# %%
yellow_tip.shape
# Out:
# (5373,)

# %%
# Independent T-Test
from scipy import stats
t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# Independent T-Test statistic: 17.05932566128597
# P-value: 7.791088119489453e-64

# %%
alpha=0.05 # significance level
if p_val < alpha:
    print("Reject null hypothesis: The tip for yellow category is different that of green")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis: The tip for yellow category is different that of green

# %%
# There is effect of color on tip column

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
sns.barplot(x=df.payment, y=df.tip, estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.barplot(x=df.payment, y=df.tip, estimator='std')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.histplot(x=df.tip,hue=df.payment,kde=True,palette={'yellow','green'})
plt.show()

# %%
credit_card=df['tip'][df['payment']=='credit card']
cash=df['tip'][df['payment']=='cash']

# %%
from scipy import stats
t_stat, p_val = stats.ttest_ind(credit_card,cash)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# Independent T-Test statistic: 49.09538452722153
# P-value: 0.0

# %%
alpha=0.05 # significance level
if p_val < alpha:
    print("Reject null hypothesis: The tip for yellow category is different that of green")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis: The tip for yellow category is different that of green

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sns.countplot(x=df['pickup_borough'],palette='Set1') # univariate
# Out:
# C:\Users\gurra\AppData\Local\Temp\ipykernel_23088\1630608595.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'],palette='Set1') # univariate
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# Out:
# C:\Users\gurra\AppData\Local\Temp\ipykernel_23088\2462997792.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %%
sns.histplot(x=df.tip,hue=df.pickup_borough,kde=True,palette='Set1')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # ANOVA Test
#
# **Definition:** ANOVA (Analysis of Variance) compares means of **three or more groups**.
#
# **Example:** Compare **Spending Score** across different **Regions**.
#
# **Hypotheses:**
# - H0: distribution of tip is the same across all pickup_borough categories
# - H1: At least one category has a different distribution of tip

# %%
manhattan_tip=df['tip'][df['pickup_borough']=='Manhattan']
Queens_tip=df['tip'][df['pickup_borough']=='Queens']
Bronx_tip=df['tip'][df['pickup_borough']=='Bronx']
Brooklyn_tip=df['tip'][df['pickup_borough']=='Brooklyn']

# %%
from scipy import stats

f_stat, p_val = stats.f_oneway(manhattan_tip, Queens_tip, Bronx_tip, Brooklyn_tip)
#print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: ")
# Out:
# P-value: 5.155109332424193e-58
# Reject null hypothesis:

# %% [markdown]
# # Post-hoc Test: Tukey HSD
#
# **Definition:** After ANOVA indicates a significant difference, Tukey HSD helps identify **which pairs of groups differ significantly**.
#
# **Example:** Compare **Spending Score** between different **Regions** to see which regions differ.
#
# **Hypotheses for Tukey test (for each pair of groups):**
# - H0: distribution of group1 = distribution of group2
# - H1: distribution of group1 ≠ distribution of group2

# %%
df.pickup_borough.unique()
df.pickup_borough.value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
df = df[df.pickup_borough.notna()]

# %%
df['pickup_borough'] = df['pickup_borough'].astype(str)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.pickup_borough, alpha=0.05)
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.2.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gurra\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df['dropoff_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Brooklyn', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
df['dropoff_borough'].value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
sns.countplot(x=df['dropoff_borough'], palette='Set1')  # univariate
# Out:
# C:\Users\gurra\AppData\Local\Temp\ipykernel_23088\2826565184.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'], palette='Set1')  # univariate
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
df['tip'].groupby(df['dropoff_borough']).mean()
# Out:
# dropoff_borough
# Bronx             0.534706
# Brooklyn          1.921590
# Manhattan         1.964321
# Queens            2.422022
# Staten Island    14.165000
# Name: tip, dtype: float64

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2')
# Out:
# C:\Users\gurra\AppData\Local\Temp\ipykernel_23088\3497531043.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['dropoff_borough']).std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
sns.histplot(x=df.tip, hue=df.dropoff_borough, kde=True, palette='Set1')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
manhattan_tip=df['tip'][df['dropoff_borough']=='Manhattan']
Queens_tip=df['tip'][df['dropoff_borough']=='Queens']
Bronx_tip=df['tip'][df['dropoff_borough']=='Bronx']
Brooklyn_tip=df['tip'][df['dropoff_borough']=='Brooklyn']
Staten_Islans_tip=df['tip'][df['dropoff_borough']=='Staten Island']

# %%
f_stat, p_val = stats.f_oneway(manhattan_tip, Queens_tip, Bronx_tip, Brooklyn_tip,Staten_Islans_tip)
#print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: ")
# Out:
# P-value: 5.87859571331583e-26
# Reject null hypothesis:

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothesis:")
# Out:
# Reject null hypothesis:

# %%
df['dropoff_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Brooklyn', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
df = df[df['dropoff_borough'].notna()]

# %%
df['dropoff_borough'] = df['dropoff_borough'].astype(str)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# Perform Tukey HSD
tukey_result=pairwise_tukeyhsd(endog=df.tip,groups=df.dropoff_borough,alpha=0.05)
print(tukey_result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
categories=[group['tip'].values for name,group in df.groupby('dropoff_zone')]
f_stat, p_val = stats.f_oneway(*categories)
#print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: ")
# Out:
# P-value: 1.3107168403750418e-120
# Reject null hypothesis:

# %%
categories=[group['tip'].values for name,group in df.groupby('pickup_zone')]
f_stat, p_val = stats.f_oneway(*categories)
#print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: ")
# Out:
# P-value: 7.892434822142503e-169
# Reject null hypothesis:

# %%
sns.histplot(df['tip'],kde=True)
plt.show()

# %%
sns.histplot(df['passengers'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.passengers)
plt.show()

# %%
r, p_val = stats.pearsonr(df['tip' ],df['passengers' ])
print("correlation", r)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print ("Fail to reject null hypothesis: ")
# Out:
# correlation 0.017838280361313734
# P-value: 0.1555196950329863
# Fail to reject null hypothesis:

# %%
r, p_val = stats.spearmanr(df['tip' ],df['passengers' ])
print("correlation", r)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: There is no relationship")
else:
    print ("Fail to reject null hypothesis:There is significant relationship ")
# Out:
# correlation 0.027509812818779178
# P-value: 0.028480753176042872
# Reject null hypothesis: There is no relationship

# %%
sns.histplot(df['fare'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.fare)
plt.show()

# %%
r, p_val = stats.pearsonr(df['tip' ],df['fare' ])
print("correlation", r)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print ("Fail to reject null hypothesis: ")
# Out:
# correlation 0.4871008907735595
# P-value: 0.0
# Reject null hypothesis:

# %%
sns.histplot(df['distance'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.distance)
plt.show()

# %%
r, p_val = stats.pearsonr(df['tip' ],df['distance' ])
print("correlation", r)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print ("Fail to reject null hypothesis: ")
# Out:
# correlation 0.4769796821455605
# P-value: 0.0
# Reject null hypothesis:

# %%
nm=df[['fare','tip','tolls','distance','passengers']]

# %%
sns.heatmap(nm.corr(), annot=True, cmap="Blues")
plt.show()

# %%
df['pickup'].dt.day
# Out:
# 0       23
# 1        4
# 2       27
# 3       10
# 4       30
#         ..
# 6336    31
# 6337    31
# 6338    23
# 6339     4
# 6340    13
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6336    3
# 6337    3
# 6338    3
# 6339    3
# 6340    3
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month_name()
# Out:
# 0       March
# 1       March
# 2       March
# 3       March
# 4       March
#         ...
# 6336    March
# 6337    March
# 6338    March
# 6339    March
# 6340    March
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.quarter
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6336    1
# 6337    1
# 6338    1
# 6339    1
# 6340    1
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.day_name()
# Out:
# 0        Saturday
# 1          Monday
# 2       Wednesday
# 3          Sunday
# 4        Saturday
#           ...
# 6336       Sunday
# 6337       Sunday
# 6338     Saturday
# 6339       Monday
# 6340    Wednesday
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.weekday
# Out:
# 0       5
# 1       0
# 2       2
# 3       6
# 4       5
#        ..
# 6336    6
# 6337    6
# 6338    5
# 6339    0
# 6340    2
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.minute
# Out:
# 0       21
# 1       11
# 2       53
# 3       23
# 4       27
#         ..
# 6336    51
# 6337    38
# 6338    55
# 6339     9
# 6340    31
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.second
# Out:
# 0        9
# 1       55
# 2        1
# 3       59
# 4       42
#         ..
# 6336    53
# 6337     0
# 6338    18
# 6339    25
# 6340    22
# Name: pickup, Length: 6341, dtype: int32

# %%
len(df['pickup'].unique())
# Out:
# 6322

# %%
df['pickup_month']=df['pickup'].dt.month_name()

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# 1  Upper West Side South      Manhattan       Manhattan        March
# 2           West Village      Manhattan       Manhattan        March
# 3         Yorkville West      Manhattan       Manhattan        March
# 4         Yorkville West      Manhattan       Manhattan        March

# %%
df['pickup_year']=df['pickup'].dt.year

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# 1  Upper West Side South      Manhattan       Manhattan        March
# 2           West Village      Manhattan       Manhattan        March
# 3         Yorkville West      Manhattan       Manhattan        March
# 4         Yorkville West      Manhattan       Manhattan        March
#
#    pickup_year
# 0         2019
# 1         2019
# 2         2019
# 3         2019
# 4         2019

# %%
df['pickup_day']=df['pickup'].dt.day

# %%
df['pickup_dayname']=df['pickup'].dt.day_name()

# %%
df['pickup_hour']=df['pickup'].dt.hour

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# 1  Upper West Side South      Manhattan       Manhattan        March
# 2           West Village      Manhattan       Manhattan        March
# 3         Yorkville West      Manhattan       Manhattan        March
# 4         Yorkville West      Manhattan       Manhattan        March
#
#    pickup_year  pickup_day pickup_dayname  pickup_hour
# 0         2019          23       Saturday           20
# 1         2019           4         Monday           16
# 2         2019          27      Wednesday           17
# 3         2019          10         Sunday            1
# 4         2019          30       Saturday           13

# %%
df.pickup_month.value_counts()
# Out:
# pickup_month
# March       6340
# February       1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['pickup_month'])
# Out:
# <Axes: xlabel='pickup_month'>

# %%
df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_dayname']=df['dropoff'].dt.day_name()
df['dropoff_hour']=df['dropoff'].dt.hour
df['dropoff_minute']=df['dropoff'].dt.minute
df['dropoff_second']=df['dropoff'].dt.second
df['dropoff_quarter']=df['dropoff'].dt.quarter

# %%
df.shape
# Out:
# (6341, 26)

# %%
df['dropoff_day']=df['dropoff'].dt.day

# %%
df.shape
# Out:
# (6341, 27)

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment  ... pickup_dayname pickup_hour  \
# 0    0.0  12.95  yellow  credit card  ...       Saturday          20
# 1    0.0   9.30  yellow         cash  ...         Monday          16
# 2    0.0  14.16  yellow  credit card  ...      Wednesday          17
# 3    0.0  36.95  yellow  credit card  ...         Sunday           1
# 4    0.0  13.40  yellow  credit card  ...       Saturday          13
#
#   dropoff_month dropoff_year dropoff_dayname  dropoff_hour  dropoff_minute  \
# 0         March         2019        Saturday            20              27
# 1         March         2019          Monday            16              19
# 2         March         2019       Wednesday            18               0
# 3         March         2019          Sunday             1              49
# 4         March         2019        Saturday            13              37
#
#   dropoff_second  dropoff_quarter dropoff_day
# 0             24                1          23
# 1              0                1           4
# 2             25                1          27
# 3             51                1          10
# 4             14                1          30
#
# [5 rows x 27 columns]

# %%
r, p_val = stats.spearmanr(df['tip' ],df['dropoff_quarter' ])
print("correlation", r)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: ")
else:
    print ("Fail to reject null hypothesis: ")
# Out:
# correlation -0.014378341502159876
# P-value: 0.25229761827973424
# Fail to reject null hypothesis:

# %%
cols = [
    'pickup','dropoff',
    'pickup_month','pickup_second','pickup_minute','pickup_day','pickup_year','pickup_quarter',
    'dropoff_day','dropoff_month','dropoff_year','dropoff_minute','dropoff_second','dropoff_quarter'
]

df.drop(columns=cols, inplace=True, errors='ignore')

# %%
df.head()
# Out:
#    passengers  distance  fare   tip  tolls  total   color      payment  \
# 0           1      1.60   7.0  2.15    0.0  12.95  yellow  credit card
# 1           1      0.79   5.0  0.00    0.0   9.30  yellow         cash
# 2           1      1.37   7.5  2.36    0.0  14.16  yellow  credit card
# 3           1      7.70  27.0  6.15    0.0  36.95  yellow  credit card
# 4           3      2.16   9.0  1.10    0.0  13.40  yellow  credit card
#
#              pickup_zone           dropoff_zone pickup_borough  \
# 0        Lenox Hill West    UN/Turtle Bay South      Manhattan
# 1  Upper West Side South  Upper West Side South      Manhattan
# 2          Alphabet City           West Village      Manhattan
# 3              Hudson Sq         Yorkville West      Manhattan
# 4           Midtown East         Yorkville West      Manhattan
#
#   dropoff_borough pickup_dayname  pickup_hour dropoff_dayname  dropoff_hour
# 0       Manhattan       Saturday           20        Saturday            20
# 1       Manhattan         Monday           16          Monday            16
# 2       Manhattan      Wednesday           17       Wednesday            18
# 3       Manhattan         Sunday            1          Sunday             1
# 4       Manhattan       Saturday           13        Saturday            13

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
cat= ['color','payment','pickup_zone','dropoff_zone','dropoff_borough','pickup_borough','pickup_dayname','dropoff_dayname']
for i in cat:
    df[i]=lb.fit_transform(df[i])

# %%
cont=['fare','tolls','total','distance']
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df[cont]=st.fit_transform(df[cont])

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('tip',axis=1)
y=df.tip

# %%
print(x.shape)
print(y.shape)
# Out:
# (6341, 15)
# (6341,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x,y,
    test_size=0.25
)

# %%
print('X train shape:',x_train.shape)
print('Y train shape:',y_train.shape)
print('X test shape:',x_test.shape)
print('Y test shape:',y_test.shape)
# Out:
# X train shape: (4755, 15)
# Y train shape: (4755,)
# X test shape: (1586, 15)
# Y test shape: (1586,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-3.32985283e-03,  1.62304412e-01, -7.88135945e+00, -9.96930528e-01,
#         9.69681419e+00, -1.21758258e+00,  5.32141456e-01, -8.10801817e-04,
#        -1.63102728e-03,  1.85362024e-01, -1.66834483e-02, -1.09367559e-02,
#        -1.68923823e-02,  1.05858236e-02, -2.35417340e-04])

# %%
model.intercept_
# Out:
# np.float64(2.8053321666719246)

# %%
y_train_pred=model.predict(x_train)
train_score=model.score(x_train,y_train)
print("Model Training Score: ",train_score)
# Out:
# Model Training Score:  0.926288552099597

# %%
y_test_pred=model.predict(x_test)
test_score=model.score(x_test,y_test)
print("Model Training Score: ",test_score)
# Out:
# Model Training Score:  0.9182052310779534

# %%
from sklearn.metrics import root_mean_squared_error,mean_squared_error,mean_absolute_error,r2_score

# %%
root_mean_squared_error(y_train,y_train_pred)
# Out:
# 0.6412581618974992

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 0.41121203020015923

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.42992550597688517

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.926288552099597
